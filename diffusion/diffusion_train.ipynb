# %%
import datetime
import itertools
import math
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
import os
import pdb
import sys
import xarray as xr
from tqdm import tqdm
from PIL import Image

sys.path.append('/home/quahb/caipi_denoising/src')

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/home/quahb/.conda/pkgs/cuda-nvcc-12.1.105-0'
os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
from tensorflow import keras
from modeling.DiffusionModel import build_model, DiffusionModel
from preparation.prepare_dataset import np_to_tfdataset
from preparation.data_io import load_dataset
from preparation.preprocessing_pipeline import fourier_transform, inverse_fourier_transform, low_pass_filter, rescale_magnitude
from utils.dct import dct2, idct2
from utils.GaussianDiffusion import GaussianDiffusion
from utils.vizualization_tools import plot2, plot4, plot_slices, plot_patches

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Hyperparams

# %%
load_epoch = 0 # set to 0 to train from scratch

train_batch_size = 8
inference_batch_size = 16
num_epochs = 301  # add one so it trains one over ten
total_timesteps = 1000
norm_groups = 8  # Number of groups used in GroupNormalization layer
learning_rate = 2e-4
image_embedding = True

img_size = 384
img_channels = 1

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2  # Number of residual blocks

# %% [markdown]
# # Train Network

# %% [markdown]
# ## 1. Dataset

# %%
images = load_dataset('/home/quahb/caipi_denoising/data/datasets/unaccelerated/magnitude_2d_full/labels/', 2, 'full')
images = images[0]
images.shape

# %%
tf_images = np_to_tfdataset(images, batch_size=train_batch_size)
train_ds = tf_images

train_ds = (
    tf_images.prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ## 2. Build Network

# %%
diffusion_model_name = f'diffusion_imgemb_models/diffusion_ep{load_epoch}.hd5'
ema_diffusion_model_name = f'diffusion_imgemb_models/ema_diffusion_ep{load_epoch}.hd5'

# Build the unet model
gpus = ['/GPU:0', '/GPU:1', '/GPU:2', '/GPU:3']
strategy = tf.distribute.MirroredStrategy(devices=gpus)
with strategy.scope():
    network = build_model(
        img_size=img_size,
        img_channels=img_channels,
        widths=widths,
        has_attention=has_attention,
        num_res_blocks=num_res_blocks,
        norm_groups=norm_groups,
        activation_fn=keras.activations.swish,
        #image_embedding=image_embedding,
    )
    ema_network = build_model(
        img_size=img_size,
        img_channels=img_channels,
        widths=widths,
        has_attention=has_attention,
        num_res_blocks=num_res_blocks,
        norm_groups=norm_groups,
        activation_fn=keras.activations.swish,
        #image_embedding=image_embedding,
    )

    if load_epoch == 0:
        ema_network.set_weights(network.get_weights())  # Initially the weights are the same
    else:
        network.load_weights(diffusion_model_name)
        ema_network.load_weights(ema_diffusion_model_name)

    # Get an instance of the Gaussian Diffusion utilities
    gdf_util = GaussianDiffusion(timesteps=total_timesteps)

    # Get the model
    model = DiffusionModel(
        network=network,
        ema_network=ema_network,
        gdf_util=gdf_util,
        timesteps=total_timesteps,
        #image_embedding=image_embedding
    )
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
    )
    
model.network.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# widths
# [64, 128, 256, 512]
# attention
# [False, False, True, True]
# widths
# [64, 128, 256, 512]
# attention
# [False, False, True, True]
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  time_input (InputLayer)        [(None,)]            0           []
#
#  time_embedding (TimeEmbedding)  (None, 256)         0           ['time_input[0][0]']
#
#  image_input (InputLayer)       [(None, 384, 384, 1  0           []
#                                 )]
#
#  dense (Dense)                  (None, 256)          65792       ['time_embedding[0][0]']
#
#  conv2d (Conv2D)                (None, 384, 384, 64  640         ['image_input[0][0]']
#                                 )
#
#  dense_1 (Dense)                (None, 256)          65792       ['dense[0][0]']
#
#  group_normalization (GroupNorm  (None, 384, 384, 64  128        ['conv2d[0][0]']
#  alization)                     )
#
#  tf.nn.silu (TFOpLambda)        (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_1 (TFOpLambda)      (None, 384, 384, 64  0           ['group_normalization[0][0]']
#                                 )
#
#  dense_2 (Dense)                (None, 64)           16448       ['tf.nn.silu[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 384, 384, 64  36928       ['tf.nn.silu_1[0][0]']
#                                 )
#
#  tf.__operators__.getitem (Slic  (None, 1, 1, 64)    0           ['dense_2[0][0]']
#  ingOpLambda)
#
#  add (Add)                      (None, 384, 384, 64  0           ['conv2d_1[0][0]',
#                                 )                                 'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  group_normalization_1 (GroupNo  (None, 384, 384, 64  128        ['add[0][0]']
#  rmalization)                   )
#
#  tf.nn.silu_2 (TFOpLambda)      (None, 384, 384, 64  0           ['group_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 384, 384, 64  36928       ['tf.nn.silu_2[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 384, 384, 64  0           ['conv2d_2[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  group_normalization_2 (GroupNo  (None, 384, 384, 64  128        ['add_1[0][0]']
#  rmalization)                   )
#
#  tf.nn.silu_3 (TFOpLambda)      (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_4 (TFOpLambda)      (None, 384, 384, 64  0           ['group_normalization_2[0][0]']
#                                 )
#
#  dense_3 (Dense)                (None, 64)           16448       ['tf.nn.silu_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 384, 384, 64  36928       ['tf.nn.silu_4[0][0]']
#                                 )
#
#  tf.__operators__.getitem_1 (Sl  (None, 1, 1, 64)    0           ['dense_3[0][0]']
#  icingOpLambda)
#
#  add_2 (Add)                    (None, 384, 384, 64  0           ['conv2d_3[0][0]',
#                                 )                                 'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  group_normalization_3 (GroupNo  (None, 384, 384, 64  128        ['add_2[0][0]']
#  rmalization)                   )
#
#  tf.nn.silu_5 (TFOpLambda)      (None, 384, 384, 64  0           ['group_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 384, 384, 64  36928       ['tf.nn.silu_5[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 384, 384, 64  0           ['conv2d_4[0][0]',
#                                 )                                 'add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 192, 192, 64  36928       ['add_3[0][0]']
#                                 )
#
#  group_normalization_4 (GroupNo  (None, 192, 192, 64  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  tf.nn.silu_6 (TFOpLambda)      (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_7 (TFOpLambda)      (None, 192, 192, 64  0           ['group_normalization_4[0][0]']
#                                 )
#
#  dense_4 (Dense)                (None, 128)          32896       ['tf.nn.silu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 192, 192, 12  73856       ['tf.nn.silu_7[0][0]']
#                                 8)
#
#  tf.__operators__.getitem_2 (Sl  (None, 1, 1, 128)   0           ['dense_4[0][0]']
#  icingOpLambda)
#
#  add_4 (Add)                    (None, 192, 192, 12  0           ['conv2d_7[0][0]',
#                                 8)                                'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  group_normalization_5 (GroupNo  (None, 192, 192, 12  256        ['add_4[0][0]']
#  rmalization)                   8)
#
#  tf.nn.silu_8 (TFOpLambda)      (None, 192, 192, 12  0           ['group_normalization_5[0][0]']
#                                 8)
#
#  conv2d_8 (Conv2D)              (None, 192, 192, 12  147584      ['tf.nn.silu_8[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, 192, 192, 12  8320        ['conv2d_5[0][0]']
#                                 8)
#
#  add_5 (Add)                    (None, 192, 192, 12  0           ['conv2d_8[0][0]',
#                                 8)                                'conv2d_6[0][0]']
#
#  group_normalization_6 (GroupNo  (None, 192, 192, 12  256        ['add_5[0][0]']
#  rmalization)                   8)
#
#  tf.nn.silu_9 (TFOpLambda)      (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_10 (TFOpLambda)     (None, 192, 192, 12  0           ['group_normalization_6[0][0]']
#                                 8)
#
#  dense_5 (Dense)                (None, 128)          32896       ['tf.nn.silu_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 192, 192, 12  147584      ['tf.nn.silu_10[0][0]']
#                                 8)
#
#  tf.__operators__.getitem_3 (Sl  (None, 1, 1, 128)   0           ['dense_5[0][0]']
#  icingOpLambda)
#
#  add_6 (Add)                    (None, 192, 192, 12  0           ['conv2d_9[0][0]',
#                                 8)                                'tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  group_normalization_7 (GroupNo  (None, 192, 192, 12  256        ['add_6[0][0]']
#  rmalization)                   8)
#
#  tf.nn.silu_11 (TFOpLambda)     (None, 192, 192, 12  0           ['group_normalization_7[0][0]']
#                                 8)
#
#  conv2d_10 (Conv2D)             (None, 192, 192, 12  147584      ['tf.nn.silu_11[0][0]']
#                                 8)
#
#  add_7 (Add)                    (None, 192, 192, 12  0           ['conv2d_10[0][0]',
#                                 8)                                'add_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 96, 96, 128)  147584      ['add_7[0][0]']
#
#  group_normalization_8 (GroupNo  (None, 96, 96, 128)  256        ['conv2d_11[0][0]']
#  rmalization)
#
#  tf.nn.silu_12 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_13 (TFOpLambda)     (None, 96, 96, 128)  0           ['group_normalization_8[0][0]']
#
#  dense_6 (Dense)                (None, 256)          65792       ['tf.nn.silu_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 96, 96, 256)  295168      ['tf.nn.silu_13[0][0]']
#
#  tf.__operators__.getitem_4 (Sl  (None, 1, 1, 256)   0           ['dense_6[0][0]']
#  icingOpLambda)
#
#  add_8 (Add)                    (None, 96, 96, 256)  0           ['conv2d_13[0][0]',
#                                                                   'tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  group_normalization_9 (GroupNo  (None, 96, 96, 256)  512        ['add_8[0][0]']
#  rmalization)
#
#  tf.nn.silu_14 (TFOpLambda)     (None, 96, 96, 256)  0           ['group_normalization_9[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 96, 96, 256)  590080      ['tf.nn.silu_14[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 96, 96, 256)  33024       ['conv2d_11[0][0]']
#
#  add_9 (Add)                    (None, 96, 96, 256)  0           ['conv2d_14[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  attention_block (AttentionBloc  (None, 96, 96, 256)  263680     ['add_9[0][0]']
#  k)
#
#  group_normalization_11 (GroupN  (None, 96, 96, 256)  512        ['attention_block[0][0]']
#  ormalization)
#
#  tf.nn.silu_15 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_16 (TFOpLambda)     (None, 96, 96, 256)  0           ['group_normalization_11[0][0]']
#
#  dense_11 (Dense)               (None, 256)          65792       ['tf.nn.silu_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 96, 96, 256)  590080      ['tf.nn.silu_16[0][0]']
#
#  tf.__operators__.getitem_5 (Sl  (None, 1, 1, 256)   0           ['dense_11[0][0]']
#  icingOpLambda)
#
#  add_10 (Add)                   (None, 96, 96, 256)  0           ['conv2d_15[0][0]',
#                                                                   'tf.__operators__.getitem_5[0][0
#                                                                  ]']
#
#  group_normalization_12 (GroupN  (None, 96, 96, 256)  512        ['add_10[0][0]']
#  ormalization)
#
#  tf.nn.silu_17 (TFOpLambda)     (None, 96, 96, 256)  0           ['group_normalization_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 96, 96, 256)  590080      ['tf.nn.silu_17[0][0]']
#
#  add_11 (Add)                   (None, 96, 96, 256)  0           ['conv2d_16[0][0]',
#                                                                   'attention_block[0][0]']
#
#  attention_block_1 (AttentionBl  (None, 96, 96, 256)  263680     ['add_11[0][0]']
#  ock)
#
#  conv2d_17 (Conv2D)             (None, 48, 48, 256)  590080      ['attention_block_1[0][0]']
#
#  group_normalization_14 (GroupN  (None, 48, 48, 256)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  tf.nn.silu_18 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_19 (TFOpLambda)     (None, 48, 48, 256)  0           ['group_normalization_14[0][0]']
#
#  dense_16 (Dense)               (None, 512)          131584      ['tf.nn.silu_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 48, 48, 512)  1180160     ['tf.nn.silu_19[0][0]']
#
#  tf.__operators__.getitem_6 (Sl  (None, 1, 1, 512)   0           ['dense_16[0][0]']
#  icingOpLambda)
#
#  add_12 (Add)                   (None, 48, 48, 512)  0           ['conv2d_19[0][0]',
#                                                                   'tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  group_normalization_15 (GroupN  (None, 48, 48, 512)  1024       ['add_12[0][0]']
#  ormalization)
#
#  tf.nn.silu_20 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_15[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_20[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 48, 48, 512)  131584      ['conv2d_17[0][0]']
#
#  add_13 (Add)                   (None, 48, 48, 512)  0           ['conv2d_20[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  attention_block_2 (AttentionBl  (None, 48, 48, 512)  1051648    ['add_13[0][0]']
#  ock)
#
#  group_normalization_17 (GroupN  (None, 48, 48, 512)  1024       ['attention_block_2[0][0]']
#  ormalization)
#
#  tf.nn.silu_21 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_22 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_17[0][0]']
#
#  dense_21 (Dense)               (None, 512)          131584      ['tf.nn.silu_21[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_22[0][0]']
#
#  tf.__operators__.getitem_7 (Sl  (None, 1, 1, 512)   0           ['dense_21[0][0]']
#  icingOpLambda)
#
#  add_14 (Add)                   (None, 48, 48, 512)  0           ['conv2d_21[0][0]',
#                                                                   'tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  group_normalization_18 (GroupN  (None, 48, 48, 512)  1024       ['add_14[0][0]']
#  ormalization)
#
#  tf.nn.silu_23 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_23[0][0]']
#
#  add_15 (Add)                   (None, 48, 48, 512)  0           ['conv2d_22[0][0]',
#                                                                   'attention_block_2[0][0]']
#
#  attention_block_3 (AttentionBl  (None, 48, 48, 512)  1051648    ['add_15[0][0]']
#  ock)
#
#  group_normalization_20 (GroupN  (None, 48, 48, 512)  1024       ['attention_block_3[0][0]']
#  ormalization)
#
#  tf.nn.silu_24 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_25 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_20[0][0]']
#
#  dense_26 (Dense)               (None, 512)          131584      ['tf.nn.silu_24[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_25[0][0]']
#
#  tf.__operators__.getitem_8 (Sl  (None, 1, 1, 512)   0           ['dense_26[0][0]']
#  icingOpLambda)
#
#  add_16 (Add)                   (None, 48, 48, 512)  0           ['conv2d_23[0][0]',
#                                                                   'tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  group_normalization_21 (GroupN  (None, 48, 48, 512)  1024       ['add_16[0][0]']
#  ormalization)
#
#  tf.nn.silu_26 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_26[0][0]']
#
#  add_17 (Add)                   (None, 48, 48, 512)  0           ['conv2d_24[0][0]',
#                                                                   'attention_block_3[0][0]']
#
#  attention_block_4 (AttentionBl  (None, 48, 48, 512)  1051648    ['add_17[0][0]']
#  ock)
#
#  group_normalization_23 (GroupN  (None, 48, 48, 512)  1024       ['attention_block_4[0][0]']
#  ormalization)
#
#  tf.nn.silu_27 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_28 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_23[0][0]']
#
#  dense_31 (Dense)               (None, 512)          131584      ['tf.nn.silu_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_28[0][0]']
#
#  tf.__operators__.getitem_9 (Sl  (None, 1, 1, 512)   0           ['dense_31[0][0]']
#  icingOpLambda)
#
#  add_18 (Add)                   (None, 48, 48, 512)  0           ['conv2d_25[0][0]',
#                                                                   'tf.__operators__.getitem_9[0][0
#                                                                  ]']
#
#  group_normalization_24 (GroupN  (None, 48, 48, 512)  1024       ['add_18[0][0]']
#  ormalization)
#
#  tf.nn.silu_29 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_29[0][0]']
#
#  add_19 (Add)                   (None, 48, 48, 512)  0           ['conv2d_26[0][0]',
#                                                                   'attention_block_4[0][0]']
#
#  concatenate (Concatenate)      (None, 48, 48, 1024  0           ['add_19[0][0]',
#                                 )                                 'attention_block_3[0][0]']
#
#  group_normalization_25 (GroupN  (None, 48, 48, 1024  2048       ['concatenate[0][0]']
#  ormalization)                  )
#
#  tf.nn.silu_30 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_31 (TFOpLambda)     (None, 48, 48, 1024  0           ['group_normalization_25[0][0]']
#                                 )
#
#  dense_32 (Dense)               (None, 512)          131584      ['tf.nn.silu_30[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 48, 48, 512)  4719104     ['tf.nn.silu_31[0][0]']
#
#  tf.__operators__.getitem_10 (S  (None, 1, 1, 512)   0           ['dense_32[0][0]']
#  licingOpLambda)
#
#  add_20 (Add)                   (None, 48, 48, 512)  0           ['conv2d_28[0][0]',
#                                                                   'tf.__operators__.getitem_10[0][
#                                                                  0]']
#
#  group_normalization_26 (GroupN  (None, 48, 48, 512)  1024       ['add_20[0][0]']
#  ormalization)
#
#  tf.nn.silu_32 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_32[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 48, 48, 512)  524800      ['concatenate[0][0]']
#
#  add_21 (Add)                   (None, 48, 48, 512)  0           ['conv2d_29[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  attention_block_5 (AttentionBl  (None, 48, 48, 512)  1051648    ['add_21[0][0]']
#  ock)
#
#  concatenate_1 (Concatenate)    (None, 48, 48, 1024  0           ['attention_block_5[0][0]',
#                                 )                                 'attention_block_2[0][0]']
#
#  group_normalization_28 (GroupN  (None, 48, 48, 1024  2048       ['concatenate_1[0][0]']
#  ormalization)                  )
#
#  tf.nn.silu_33 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_34 (TFOpLambda)     (None, 48, 48, 1024  0           ['group_normalization_28[0][0]']
#                                 )
#
#  dense_37 (Dense)               (None, 512)          131584      ['tf.nn.silu_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 48, 48, 512)  4719104     ['tf.nn.silu_34[0][0]']
#
#  tf.__operators__.getitem_11 (S  (None, 1, 1, 512)   0           ['dense_37[0][0]']
#  licingOpLambda)
#
#  add_22 (Add)                   (None, 48, 48, 512)  0           ['conv2d_31[0][0]',
#                                                                   'tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  group_normalization_29 (GroupN  (None, 48, 48, 512)  1024       ['add_22[0][0]']
#  ormalization)
#
#  tf.nn.silu_35 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_35[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 48, 48, 512)  524800      ['concatenate_1[0][0]']
#
#  add_23 (Add)                   (None, 48, 48, 512)  0           ['conv2d_32[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  attention_block_6 (AttentionBl  (None, 48, 48, 512)  1051648    ['add_23[0][0]']
#  ock)
#
#  concatenate_2 (Concatenate)    (None, 48, 48, 768)  0           ['attention_block_6[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  group_normalization_31 (GroupN  (None, 48, 48, 768)  1536       ['concatenate_2[0][0]']
#  ormalization)
#
#  tf.nn.silu_36 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_37 (TFOpLambda)     (None, 48, 48, 768)  0           ['group_normalization_31[0][0]']
#
#  dense_42 (Dense)               (None, 512)          131584      ['tf.nn.silu_36[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 48, 48, 512)  3539456     ['tf.nn.silu_37[0][0]']
#
#  tf.__operators__.getitem_12 (S  (None, 1, 1, 512)   0           ['dense_42[0][0]']
#  licingOpLambda)
#
#  add_24 (Add)                   (None, 48, 48, 512)  0           ['conv2d_34[0][0]',
#                                                                   'tf.__operators__.getitem_12[0][
#                                                                  0]']
#
#  group_normalization_32 (GroupN  (None, 48, 48, 512)  1024       ['add_24[0][0]']
#  ormalization)
#
#  tf.nn.silu_38 (TFOpLambda)     (None, 48, 48, 512)  0           ['group_normalization_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 48, 48, 512)  2359808     ['tf.nn.silu_38[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 48, 48, 512)  393728      ['concatenate_2[0][0]']
#
#  add_25 (Add)                   (None, 48, 48, 512)  0           ['conv2d_35[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  attention_block_7 (AttentionBl  (None, 48, 48, 512)  1051648    ['add_25[0][0]']
#  ock)
#
#  up_sampling2d (UpSampling2D)   (None, 96, 96, 512)  0           ['attention_block_7[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 96, 96, 512)  2359808     ['up_sampling2d[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 96, 96, 768)  0           ['conv2d_36[0][0]',
#                                                                   'attention_block_1[0][0]']
#
#  group_normalization_34 (GroupN  (None, 96, 96, 768)  1536       ['concatenate_3[0][0]']
#  ormalization)
#
#  tf.nn.silu_39 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_40 (TFOpLambda)     (None, 96, 96, 768)  0           ['group_normalization_34[0][0]']
#
#  dense_47 (Dense)               (None, 256)          65792       ['tf.nn.silu_39[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 96, 96, 256)  1769728     ['tf.nn.silu_40[0][0]']
#
#  tf.__operators__.getitem_13 (S  (None, 1, 1, 256)   0           ['dense_47[0][0]']
#  licingOpLambda)
#
#  add_26 (Add)                   (None, 96, 96, 256)  0           ['conv2d_38[0][0]',
#                                                                   'tf.__operators__.getitem_13[0][
#                                                                  0]']
#
#  group_normalization_35 (GroupN  (None, 96, 96, 256)  512        ['add_26[0][0]']
#  ormalization)
#
# ...
#  tf.nn.silu_55 (TFOpLambda)     (None, 192, 192, 19  0           ['group_normalization_47[0][0]']
#                                 2)
#
#  dense_64 (Dense)               (None, 128)          32896       ['tf.nn.silu_54[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 192, 192, 12  221312      ['tf.nn.silu_55[0][0]']
#                                 8)
#
#  tf.__operators__.getitem_18 (S  (None, 1, 1, 128)   0           ['dense_64[0][0]']
#  licingOpLambda)
#
#  add_36 (Add)                   (None, 192, 192, 12  0           ['conv2d_54[0][0]',
#                                 8)                                'tf.__operators__.getitem_18[0][
#                                                                  0]']
#
#  group_normalization_48 (GroupN  (None, 192, 192, 12  256        ['add_36[0][0]']
#  ormalization)                  8)
#
#  tf.nn.silu_56 (TFOpLambda)     (None, 192, 192, 12  0           ['group_normalization_48[0][0]']
#                                 8)
#
#  conv2d_55 (Conv2D)             (None, 192, 192, 12  147584      ['tf.nn.silu_56[0][0]']
#                                 8)
#
#  conv2d_53 (Conv2D)             (None, 192, 192, 12  24704       ['concatenate_8[0][0]']
#                                 8)
#
#  add_37 (Add)                   (None, 192, 192, 12  0           ['conv2d_55[0][0]',
#                                 8)                                'conv2d_53[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 384, 384, 12  0          ['add_37[0][0]']
#                                 8)
#
#  conv2d_56 (Conv2D)             (None, 384, 384, 12  147584      ['up_sampling2d_2[0][0]']
#                                 8)
#
#  concatenate_9 (Concatenate)    (None, 384, 384, 19  0           ['conv2d_56[0][0]',
#                                 2)                                'add_3[0][0]']
#
#  group_normalization_49 (GroupN  (None, 384, 384, 19  384        ['concatenate_9[0][0]']
#  ormalization)                  2)
#
#  tf.nn.silu_57 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_58 (TFOpLambda)     (None, 384, 384, 19  0           ['group_normalization_49[0][0]']
#                                 2)
#
#  dense_65 (Dense)               (None, 64)           16448       ['tf.nn.silu_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 384, 384, 64  110656      ['tf.nn.silu_58[0][0]']
#                                 )
#
#  tf.__operators__.getitem_19 (S  (None, 1, 1, 64)    0           ['dense_65[0][0]']
#  licingOpLambda)
#
#  add_38 (Add)                   (None, 384, 384, 64  0           ['conv2d_58[0][0]',
#                                 )                                 'tf.__operators__.getitem_19[0][
#                                                                  0]']
#
#  group_normalization_50 (GroupN  (None, 384, 384, 64  128        ['add_38[0][0]']
#  ormalization)                  )
#
#  tf.nn.silu_59 (TFOpLambda)     (None, 384, 384, 64  0           ['group_normalization_50[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 384, 384, 64  36928       ['tf.nn.silu_59[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 384, 384, 64  12352       ['concatenate_9[0][0]']
#                                 )
#
#  add_39 (Add)                   (None, 384, 384, 64  0           ['conv2d_59[0][0]',
#                                 )                                 'conv2d_57[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 384, 384, 12  0           ['add_39[0][0]',
#                                 8)                                'add_1[0][0]']
#
#  group_normalization_51 (GroupN  (None, 384, 384, 12  256        ['concatenate_10[0][0]']
#  ormalization)                  8)
#
#  tf.nn.silu_60 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_61 (TFOpLambda)     (None, 384, 384, 12  0           ['group_normalization_51[0][0]']
#                                 8)
#
#  dense_66 (Dense)               (None, 64)           16448       ['tf.nn.silu_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 384, 384, 64  73792       ['tf.nn.silu_61[0][0]']
#                                 )
#
#  tf.__operators__.getitem_20 (S  (None, 1, 1, 64)    0           ['dense_66[0][0]']
#  licingOpLambda)
#
#  add_40 (Add)                   (None, 384, 384, 64  0           ['conv2d_61[0][0]',
#                                 )                                 'tf.__operators__.getitem_20[0][
#                                                                  0]']
#
#  group_normalization_52 (GroupN  (None, 384, 384, 64  128        ['add_40[0][0]']
#  ormalization)                  )
#
#  tf.nn.silu_62 (TFOpLambda)     (None, 384, 384, 64  0           ['group_normalization_52[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 384, 384, 64  36928       ['tf.nn.silu_62[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 384, 384, 64  8256        ['concatenate_10[0][0]']
#                                 )
#
#  add_41 (Add)                   (None, 384, 384, 64  0           ['conv2d_62[0][0]',
#                                 )                                 'conv2d_60[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 384, 384, 12  0           ['add_41[0][0]',
#                                 8)                                'conv2d[0][0]']
#
#  group_normalization_53 (GroupN  (None, 384, 384, 12  256        ['concatenate_11[0][0]']
#  ormalization)                  8)
#
#  tf.nn.silu_63 (TFOpLambda)     (None, 256)          0           ['dense_1[0][0]']
#
#  tf.nn.silu_64 (TFOpLambda)     (None, 384, 384, 12  0           ['group_normalization_53[0][0]']
#                                 8)
#
#  dense_67 (Dense)               (None, 64)           16448       ['tf.nn.silu_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 384, 384, 64  73792       ['tf.nn.silu_64[0][0]']
#                                 )
#
#  tf.__operators__.getitem_21 (S  (None, 1, 1, 64)    0           ['dense_67[0][0]']
#  licingOpLambda)
#
#  add_42 (Add)                   (None, 384, 384, 64  0           ['conv2d_64[0][0]',
#                                 )                                 'tf.__operators__.getitem_21[0][
#                                                                  0]']
#
#  group_normalization_54 (GroupN  (None, 384, 384, 64  128        ['add_42[0][0]']
#  ormalization)                  )
#
#  tf.nn.silu_65 (TFOpLambda)     (None, 384, 384, 64  0           ['group_normalization_54[0][0]']
#                                 )
#
#  conv2d_65 (Conv2D)             (None, 384, 384, 64  36928       ['tf.nn.silu_65[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 384, 384, 64  8256        ['concatenate_11[0][0]']
#                                 )
#
#  add_43 (Add)                   (None, 384, 384, 64  0           ['conv2d_65[0][0]',
#                                 )                                 'conv2d_63[0][0]']
#
#  group_normalization_55 (GroupN  (None, 384, 384, 64  128        ['add_43[0][0]']
#  ormalization)                  )
#
#  tf.nn.silu_66 (TFOpLambda)     (None, 384, 384, 64  0           ['group_normalization_55[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 384, 384, 1)  577         ['tf.nn.silu_66[0][0]']
#
# ==================================================================================================
# Total params: 63,198,081
# Trainable params: 63,198,081
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
s_date = datetime.date.today()

model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=train_batch_size,
    initial_epoch=load_epoch,
    callbacks=[
        keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images),
        keras.callbacks.LambdaCallback(on_epoch_end=model.save_model), 
    ],
)
